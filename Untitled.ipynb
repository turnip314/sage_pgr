# %%
R1.<x,t,y> = QQ[]
R2.<s, d> = PolynomialRing(R1, 2)

# %%
s.change_ring(QQ).is_squarefree()
# Out:
# True

# %%
flat_ring = PolynomialRing(QQ, [d,x,y,t,s]).fraction_field()

# %%
R_specialized = PolynomialRing(QQ, 2, [s,d])
R_specialized(s^2+d^2).is_squarefree()
# Out:
# True

# %%
(y^2+x^2).is_squarefree()
# Out:
# True

# %%
R2.flattening_morphism()(x).parent()
# Out:
# Multivariate Polynomial Ring in x, t, y, s, d over Rational Field

# %%
QQ.random_element(10)
# Out:
# -10/3

# %%
(s^2*d).degree(s)
# Out:
# 2

# %%
(x*s^100 + t) % (s^2-s+y)
# Out:
# (-50*x*y^49 + 20825*x*y^48 - 2598960*x*y^47 + 154143080*x*y^46 - 5317936260*x*y^45 + 119653565850*x*y^44 - 1889912732400*x*y^43 + 22057981462440*x*y^42 - 197548686920970*x*y^41 + 1397281501935165*x*y^40 - 7984465725343800*x*y^39 + 37539612570341700*x*y^38 - 147405545359541742*x*y^37 + 489462003181042451*x*y^36 - 1388818294740297792*x*y^35 + 3397378086595889760*x*y^34 - 7219428434016265740*x*y^33 + 13413576695470557606*x*y^32 - 21912870037044995008*x*y^31 + 31627280033224861216*x*y^30 - 40498346384007444240*x*y^29 + 46171702771135840360*x*y^28 - 47011188276065582912*x*y^27 + 42858025944553776096*x*y^26 - 35059031427432595752*x*y^25 + 25778699578994555700*x*y^24 - 17061084191613232800*x*y^23 + 10173461314258261040*x*y^22 - 5469191608792974920*x*y^21 + 2651487106659130740*x*y^20 - 1159120046626942400*x*y^19 + 456703981505085600*x*y^18 - 162042085745554410*x*y^17 + 51705423561053205*x*y^16 - 14810760713140560*x*y^15 + 3799541229226200*x*y^14 - 870366750378300*x*y^13 + 177366629671686*x*y
# ...

# %%
R1.<x,t,y> = QQ[]
F1 = R1.fraction_field()
x, t, y =F1.gens()
R2.<s> = PolynomialRing(F1, 1)
xgcd(x*s^100 + t, s^2-s+y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[420], line 5
#       3 x, t, y =F1.gens()
#       4 R2 = PolynomialRing(F1, Integer(1), names=('s',)); (s,) = R2._first_ngens(1)
# ----> 5 xgcd(x*s**Integer(100) + t, s**Integer(2)-s+y)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/arith/misc.py:2087, in xgcd(a, b)
#    2085     except TypeError:
#    2086         b = py_scalar_to_element(b)
# -> 2087     return a.xgcd(b)
#    2089 # xgcd for several elements (possibly more than one)
#    2090 if len(a) == 0:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:11829)()
# ...

# %%
(x*s+1).inverse()
# Out:
# 1/(x*s + 1)
